# %% [markdown]
# # Statistical and Machine Learning - Assignment 1
#
# By -  Swasthik VELLINGIRI KOWSALYA

# %% [markdown]
# # Chapter 2 - 2

# %% [markdown]
# (a) n = 500 and p = 3
# Regression and Inference
#
# (b) n = 20 and p = 13
# Classification and Prediction
#
# (c) n = 52 and p = 3
# Regression and Prediction

# %% [markdown]
# # Chapter 2 - 10

# %% [markdown]
# # 10 - A

# %%
library(MASS)
head(Boston)
# Out:
#   crim    zn indus chas nox   rm    age  dis    rad tax ptratio black  lstat
# 1 0.00632 18 2.31  0    0.538 6.575 65.2 4.0900 1   296 15.3    396.90 4.98
# 2 0.02731  0 7.07  0    0.469 6.421 78.9 4.9671 2   242 17.8    396.90 9.14
# 3 0.02729  0 7.07  0    0.469 7.185 61.1 4.9671 2   242 17.8    392.83 4.03
# 4 0.03237  0 2.18  0    0.458 6.998 45.8 6.0622 3   222 18.7    394.63 2.94
# 5 0.06905  0 2.18  0    0.458 7.147 54.2 6.0622 3   222 18.7    396.90 5.33
# 6 0.02985  0 2.18  0    0.458 6.430 58.7 6.0622 3   222 18.7    394.12 5.21
#   medv
# 1 24.0
# 2 21.6
# 3 34.7
# 4 33.4
# 5 36.2
# 6 28.7

# %%
?Boston

# %%
nrow(Boston)
ncol(Boston)

### The Boston data frame has 506 rows and 14 columns.
# Out:
# [1] 506
# [1] 14

# %% [markdown]
# 10 (B)

# %%
?Boston

# %%
## Plot --  proportion of residential land zoned for lots over 25,000 sq.ft. vs  weighted mean of distances to five Boston employment centres.

plot(Boston$zn,Boston$dis)


#Result: weighted mean of distances to five Boston employment centres is in the range of 4 to 10 for all proportion of residential land zone
# Out:
# plot without title

# %%
#PLOT - proportion of residential land zoned for lots over 25,000 sq.ft.  vs   index of accessibility to radial highways.

plot(Boston$zn,Boston$rad)

#accessibility to radial highways is in the range 0 to 10 irrespective of proportion of residential land
# Out:
# plot without title

# %%
#PLOT - proportion of residential land zoned for lots over 25,000 sq.ft.  vs   full-value property-tax rate per $10,000

plot(Boston$zn,Boston$tax)


###  full-value property-tax rate per $10,000 is highest at proportion of residential land zoned is at 75 and is highest in the range 40 to 80
# Out:
# plot without title

# %%
#PLOT - average number of rooms per dwelling vs per capita crime rate by town

plot(Boston$crim,Boston$rm)

#The crimes made are more when the rooms per dwelling is inbetween 5 and 7. And there are more less than 20 crimes
# Out:
# plot without title

# %%
##PLot -  proportion of residential land zoned vs pupil-teacher ratio by town.

plot(Boston$zn,Boston$ptratio)

#proportion of residential land zoned does not affect the pupil-teacher ratio by town much and they are in the same range.
# Out:
# plot without title

# %% [markdown]
# # 10 - (c)

# %%
###PLOT - per capita crime rate by town vs proportion of owner-occupied units built prior to 1940

plot(Boston$crim,Boston$age)

##The amount of crimes increase when the proportion of owner-occupied units built prior to 1940 increases
# Out:
# plot without title

# %%
###PLOT - per capita crime rate by town vs weighted mean of distances to five Boston employment centres

plot(Boston$crim,Boston$dis)

# The number of crimes is higher if the weighted mean of distances to five Boston employment centres is lesser than 4
# Out:
# plot without title

# %%
###PLOT - per capita crime rate by town vs pupil-teacher ratio by town.

plot(Boston$crim,Boston$pratio)

##Result - The per capita crime is very high for pupil-teacher ratio by town is less than 20.
# Out:
# plot without title

# %%
###PLOT - per capita crime rate by town vs proportion of blacks by town.

plot(Boston$crim,Boston$black)

##Higher the proportion of blacks by town, higher the per capita crime rate by town
# Out:
# plot without title

# %%
###PLOT - per capita crime rate by town vs lower status of the population

plot(Boston$crim,Boston$istat)

## per capita crime rate by town is very high if the lower status of the population is under 20.
# Out:
# plot without title

# %%
###PLOT - per capita crime rate by town vs median value of owner-occupied homes in $1000s

plot(Boston$crim,Boston$medv)

## Lesser the median value of owner-occupied homes, higher the per capita crime rates
# Out:
# plot without title

# %%
###PLOT per capita crime rate by town.

plot(Boston$crim)

## Yes, the number of crime rates is higher
# Out:
# plot without title

# %%
plot(Boston$zn, Boston$tax)
# Out:
# plot without title

# %%
plot(Boston$zn, Boston$ptratio)
# Out:
# plot without title

# %% [markdown]
# # 10 - D

# %%
summary(Boston$crim)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#  0.00632  0.08204  0.25651  3.61352  3.67708 88.97620

# %% [markdown]
# Certainly, the maximum value has a significantly higher value than the 3rd quartile

# %% [markdown]
# # Tax rates

# %%
hist(Boston$tax)
# Out:
# Plot with title "Histogram of Boston$tax"

# %% [markdown]
# # Pupil-Teacher Ratio

# %%
hist(Boston$ptratio)
# Out:
# Plot with title "Histogram of Boston$ptratio"

# %% [markdown]
# # 10 - E

# %%
table(Boston$chas)
# Out:
#   0   1
# 471  35

# %% [markdown]
# There are 35 suburbs that bound the Charles Rivers, values 1 represent those that bounded the Charles Rivers

# %% [markdown]
# # 10 - F

# %%
median(Boston$ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# # Chapter 3 - (3)

# %% [markdown]
# (a)  For a fixed value of IQ and GPA, males earn more on average than females provided that the GPA is high enough.

# %%
#(b)

Y=50+20∗(4)+0.07∗(110)+35+0.01∗(4∗110)-10∗(4∗1)
Y
# Out:
# [1] 137.1

# %% [markdown]
# (c) FALSE
#
# There is no indication that the interaction term has a low effect due to the small coefficient

# %% [markdown]
# # Chapter 3

# %% [markdown]
# # 10 - A

# %%
install.packages("ISLR")
library(ISLR)
data(Carseats)
# Out:
#   There is a binary version available but the source version is later:
#      binary source needs_compilation
# ISLR    1.2    1.4             FALSE
# installing the source package 'ISLR'

# %%
fit_regression = lm(Sales ~ Price + Urban + US, data = Carseats)
summary(fit_regression)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036  < 2e-16 ***
# Price       -0.054459   0.005242 -10.389  < 2e-16 ***
# UrbanYes    -0.021916   0.271650  -0.081    0.936
# USYes        1.200573   0.259042   4.635 4.86e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 2.2e-16

# %% [markdown]
# # 10 - B

# %% [markdown]
# Price  =  A price increase of 1 dollar results in an average decline of 54.4588492 units of sales if all other predictors remain constant.
#
# Urban = On average the units in urban locations are 21.9161508 units less than those in rural locations.
#
# US = When all other predictors are held constant, the coefficient of the "US" variable can be explained by saying that unit sales in a US store are 1200.5726978 more than in a non-US store.

# %% [markdown]
# # 10 - C

# %% [markdown]
# Sales= 13.0434689 + (-0.0544588) * Price + (-0.0219162) * Urban + (1.2005727) * US + ε

# %% [markdown]
# # 10 - D

# %% [markdown]
# Question: For which of the predictors can you reject the null hypothesis H0:βj=0 ?
#
# “Price” and “US”

# %% [markdown]
# # 10 - E

# %%
small_model = lm(Sales ~ Price + US, data = Carseats)
summary(small_model)
# Out:
# Call:
# lm(formula = Sales ~ Price + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652  < 2e-16 ***
# Price       -0.05448    0.00523 -10.416  < 2e-16 ***
# USYes        1.19964    0.25846   4.641 4.71e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 2.2e-16

# %% [markdown]
# # 10 - F

# %% [markdown]
# Smaller model have a better R2 than the bigger one.

# %% [markdown]
# # 10 - G

# %%
confint(small_model)
# Out:
#             2.5 %       97.5 %
# (Intercept) 11.79032020 14.27126531
# Price       -0.06475984 -0.04419543
# USYes        0.69151957  1.70776632

# %% [markdown]
# # 10 - H

# %%
par(mfrow = c(2, 2))
plot(small_model)

#there are a few outliers. 
# 1. higher than 2 
# 2. lower than -2)
# Out:
# Plot with title ""
